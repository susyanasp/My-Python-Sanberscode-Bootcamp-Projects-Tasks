# %%
from matplotlib import pyplot as plt
import seaborn as snsxdd
import numpy as np
import pandas as pd

# %%
df1 = sns.load_dataset('diamonds', engine='python', error_bad_lines=False, warn_bad_lines=False)
df1
df = pd.read_csv('diamonds.csv')
df_1 = df.drop(columns = ['Unnamed: 0','x','y','z'])
df_1
# Out:
#        carat        cut color clarity  depth  table  price
# 0       0.23      Ideal     E     SI2   61.5   55.0    326
# 1       0.21    Premium     E     SI1   59.8   61.0    326
# 2       0.23       Good     E     VS1   56.9   65.0    327
# 3       0.29    Premium     I     VS2   62.4   58.0    334
# 4       0.31       Good     J     SI2   63.3   58.0    335
# ...      ...        ...   ...     ...    ...    ...    ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757
# 53936   0.72       Good     D     SI1   63.1   55.0   2757
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757
#
# [53940 rows x 7 columns]

# %% [markdown]
# # Soal 1: Scatter Plot

# %% [markdown]
# Buatlah scatterplot menggunakan Seaborn dari data df di atas, variasikan menggunakan palette yang telah disediakan sehingga didapatkan output sesuai expected.

# %%
sns.set({'figure.figsize':(13,13)})
palette = "ch:r=-.2,d=.3_r"

#code here
f, ax = plt.subplots(figsize=(13, 13))
sns.despine(f, left=True, bottom=True)
clarity_ranking = ["IF", "VVS1", "VVS2", "VS1", "VS2", "SI1", "SI2", "I1"]
sns.scatterplot(x="carat", y="price",
                hue="clarity", size="depth",
                hue_order=clarity_ranking,
                palette = palette,
                sizes=(1, 8), linewidth=0,
                data=df, ax=ax)
plt.show()

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1JLtkSpx0TfSF7fMSBcZuXaY_tNkR5LYc)

# %% [markdown]
# # Soal 2: Catplot

# %% [markdown]
# Buatlah sebuah Categorical plot dengan kind = 'boxplot', sehingga diperoleh hasil seperti expected output berikut:

# %%
#code here
with sns.axes_style(style='ticks'):
    g = sns.catplot(x='clarity', y='price', data=df, order=["IF", "VVS1", "VVS2", "VS1", "VS2", "SI1", "SI2", "I1"], col='cut', col_order=['Ideal','Premium','Very Good','Good','Fair'], kind='box', showfliers=False, height=4)
    g.set_axis_labels("Clarity", "Price");

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=17mSiL-qQtFB2D8rUYB0v7d6tOrOHDoh6)

# %% [markdown]
# # Soal 3: Pair Plot

# %% [markdown]
# Ambil 300 data secara acak dari df, kemudian buat pair plotnya dari 300 data tersebut untuk kolom carat, depth, table, dan price serta markers =  ['p', 'o', 's', 'D', 'X'] sehingga dihasilkan output sesuai expected.

# %%
df_sample = df_1.sample(n=300)

#code here
sns.pairplot(df_sample, hue='cut', hue_order=["Ideal", "Premium", "Very Good", "Good", "Fair"], markers=['p','o','s','D','X'], corner=True);

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=12rStINwUNGpqZd1iIGaqzTIvw9irAkJ0)

# %% [markdown]
# # Soal 4: Joint Plot

# %% [markdown]
# Gunakan data yang sama dengan soal 3 untuk menghasilkan dua visualisasi joint plot antara carat dan price nya sesuai expected output.

# %%
#code here
with sns.axes_style('white'):
    sns.jointplot(x='carat', y='price', data=df, kind='kde')
sns.jointplot(x='carat', y='price', data=df, kind='reg');

# %% [markdown]
# Expected Output 1:
#
# ![alt text](https://drive.google.com/uc?id=17MY9L4bUSxuCIRxDl7Ey34_RrfXjlcim)
#
# Expected Output 2:
#
# ![alt text](https://drive.google.com/uc?id=1A5vQ66KLZ9sbJ_qDoAkuAF3Z213ricZW)
